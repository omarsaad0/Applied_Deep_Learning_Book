# %%
import numpy as np
import cv2
import matplotlib.image as mpimg
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
image = cv2.imread(r'C:\Users\omar saad\Desktop\SDC\Section1/highway-aerial.jpg')

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')

# %%
ROI = np.array([(0,393), (500,148), (544,145), (1023,370)], dtype=np.int32)

# %%
blank = np.zeros_like(image_gray)
blank.shape
# Out:
# (512, 1024)

# %%
mask = cv2.fillPoly(blank, ROI, 255)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-ec66ca377048> in <module>()
# ----> 1 mask = cv2.fillPoly(blank, ROI, 255)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6uw63ony\opencv\modules\imgproc\src\drawing.cpp:2395: error: (-215:Assertion failed) p.checkVector(2, CV_32S) >= 0 in function 'cv::fillPoly'
