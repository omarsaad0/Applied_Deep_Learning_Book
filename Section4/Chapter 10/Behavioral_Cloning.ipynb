# %% [markdown]
# <font size="5"> Behavioral Cloning (Omar Saad)  </font>

# %%
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Dropout, Flatten, Dense
import cv2
import pandas as pd 
import random 
import os 
import ntpath
import matplotlib.image as mpimg
from sklearn.utils import shuffle 
from sklearn.model_selection import train_test_split
from imgaug import augmenters as iaa

# %% [markdown]
# <font size="4"> Data Preparation  </font>

# %%
datadir = 'track'
columns = ['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed']
data = pd.read_csv(os.path.join(datadir, 'driving_log.csv'), names=columns)
pd.set_option('display.max_colwidth', -1)
data.head()
# Out:
# C:\Users\OMARSA~1\AppData\Local\Temp/ipykernel_3728/1135058475.py:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                         center  ...     speed
# 0  C:\UDACITY_SIMULATOR\IMG\center_2022_04_11_00_04_22_442.jpg  ...  0.000078
# 1  C:\UDACITY_SIMULATOR\IMG\center_2022_04_11_00_04_22_542.jpg  ...  0.000081
# 2  C:\UDACITY_SIMULATOR\IMG\center_2022_04_11_00_04_22_644.jpg  ...  0.046101
# 3  C:\UDACITY_SIMULATOR\IMG\center_2022_04_11_00_04_22_745.jpg  ...  0.292681
# 4  C:\UDACITY_SIMULATOR\IMG\center_2022_04_11_00_04_22_849.jpg  ...  0.876920
#
# [5 rows x 7 columns]

# %%
def path_leaf(path):
    head, tail = ntpath.split(path)   #removes the path from the file name and return only the image name 
    return(tail)

data['center'] = data['center'].apply(path_leaf)
data['left'] = data['left'].apply(path_leaf)
data['right'] = data['right'].apply(path_leaf)
data.head()
# Out:
#                                center                              left  ... reverse     speed
# 0  center_2022_04_11_00_04_22_442.jpg  left_2022_04_11_00_04_22_442.jpg  ...  0.0     0.000078
# 1  center_2022_04_11_00_04_22_542.jpg  left_2022_04_11_00_04_22_542.jpg  ...  0.0     0.000081
# 2  center_2022_04_11_00_04_22_644.jpg  left_2022_04_11_00_04_22_644.jpg  ...  0.0     0.046101
# 3  center_2022_04_11_00_04_22_745.jpg  left_2022_04_11_00_04_22_745.jpg  ...  0.0     0.292681
# 4  center_2022_04_11_00_04_22_849.jpg  left_2022_04_11_00_04_22_849.jpg  ...  0.0     0.876920
#
# [5 rows x 7 columns]
